# %% [markdown]
# # Statistical Analysis on two genomic diversity datasets:

# %% [markdown]
# 1) 1000 Genomes Project
#     - 2504 Individual Genomes
#     - 260 subpopulations
# 2) Simons Foundation Genome Diversity Project
#     - 279 Individual Genomes
#     - 127 subpopulations

# %% [markdown]
# # chromosome length dictionary

# %% [markdown]
# this is used for drawing random regions to look for genes on each chromosome

# %%
import json
import random

chrom_len_dict = {
    "1":249250621,
    "2":243199373,
    "3":198022430,
    "4":191154276,
    "5":180915260,
    "6":171115067,
    "7":159138663,
    "X":155270560,
    "8":146364022,
    "9":141213431,
    "10":135534747,
    "11":135006516,
    "12":133851895,
    "13":115169878,
    "14":107349540,
    "15":102531392,
    "16":90354753,
    "17":81195210,
    "18":78077248,
    "20":63025520,
    "Y" :59373566,
    "19":59128983,
    "22":51304566,
    "21":48129895,
}

# %% [markdown]
# # Make connection to the Simons Foundation Server

# %% [markdown]
# ( *******this is part of the code is in the development stage************* )
#
# each individual in the Simons Foundation Genome Diversity Project datasets is it's own dataset

# %%
from __future__ import print_function
import ga4gh.client.client as client
simons_client = client.HttpClient("http://10.50.100.241/")

"""
******************** get datasets and variant_sets ******************* 
"""
datasets = list(simons_client.search_datasets())

# get 1000 gneomes dataset 
dataset = simons_client.get_dataset(datasets[0].id)

vs = None
simons_csids = []
for variant_set in simons_client.search_variant_sets(dataset_id=dataset.id):
    
    print ( variant_set.name )
    callsi = list(simons_client.search_call_sets(variant_set.id))

    variant_sets = list(simons_client.search_variant_sets(dataset.id))
    variant_set_id = variant_sets[0].id

    call_set_ids = []

    for csi in callsi: call_set_ids.append(csi.id)
    simons_csids.append(call_set_ids)
# Out:
# SS6004469
# SS6004469-annotated-nh2
# LP6005592-DNA_D04
# LP6005592-DNA_D04-annotated-nh2
# LP6005677-DNA_F01
# LP6005677-DNA_F01-annotated-nh2
# LP6005442-DNA_E12
# LP6005442-DNA_E12-annotated-nh2
# LP6005443-DNA_A08
# LP6005443-DNA_A08-annotated-nh2
# LP6005441-DNA_E10
# LP6005441-DNA_E10-annotated-nh2
# LP6005443-DNA_D09
# LP6005443-DNA_D09-annotated-nh2
# LP6005443-DNA_E06
# LP6005443-DNA_E06-annotated-nh2
# LP6005442-DNA_G12
# LP6005442-DNA_G12-annotated-nh2
# LP6005441-DNA_B11
# LP6005441-DNA_B11-annotated-nh2
# LP6005442-DNA_F12
# LP6005442-DNA_F12-annotated-nh2
# LP6005441-DNA_E09
# LP6005441-DNA_E09-annotated-nh2
# LP6005441-DNA_C06
# LP6005441-DNA_C06-annotated-nh2
# LP6005443-DNA_C07
# LP6005443-DNA_C07-annotated-nh2
# SS6004474
# SS6004474-annotated-nh2
# LP6005442-DNA_D10
# LP6005442-DNA_D10-annotated-nh2
# LP6005443-DNA_H08
# LP6005443-DNA_H08-annotated-nh2
# LP6007068-DNA_A01
# LP6007068-DNA_A01-annotated-nh2
# LP6005442-DNA_B10
# LP6005442-DNA_B10-annotated-nh2
# ...

# %% [markdown]
# # Make connection to the 1000 Genomes Project Server

# %% [markdown]
# all of the 1000 genomes dataset is located in a single variant set: phase-3-release

# %%
from __future__ import print_function
import ga4gh.client.client as client

client = client.HttpClient("http://1kgenomes.ga4gh.org")

"""
******************** get datasets and variant_sets ******************* 
"""
datasets = list(client.search_datasets())

# get 1000 gneomes dataset 
dataset = client.get_dataset(datasets[0].id)

release = None
functional = None
for variant_set in client.search_variant_sets(dataset_id=dataset.id):
    if variant_set.name == "phase3-release":
        release = variant_set
    else:
        functional = variant_set

callsi = list(client.search_call_sets(release.id))

variant_sets = list(client.search_variant_sets(dataset.id))
variant_set_id = variant_sets[0].id

call_set_ids = []

for csi in callsi: call_set_ids.append(csi.id)

# %% [markdown]
# # get the feature set

# %% [markdown]
# This is used to find the names of genes and the regions that they are found in. Because gene regions are globally recognized we can use the 1000 genomes client to obtain them.

# %%
for feature_set in client.search_feature_sets(dataset_id=dataset.id):
    if feature_set.name == "gencode_v24lift37":
        gencode = feature_set

feature_set = client.get_feature_set(feature_set_id=gencode.id)

# %% [markdown]
# # get the random regions

# %% [markdown]
# for getting random regions on each chromosome

# %%
def get_random_regions():
    """
    randomly samples a position in each chromosome
    :return: a dictionary of chromosome number to random position
    """

    chromosomes = chrom_len_dict.keys()

    random_regions_dict = {}
    for i in chromosomes:

        random_region = random.randrange(0,chrom_len_dict[i])

        random_regions_dict[i] = random_region

    return random_regions_dict

# %% [markdown]
# # map the individuals call set ids to each population group

# %%
# for getting data on populations in 1000 genomes 
def map_call_set_ids_to_population_group():
    """
    This allows for the individuals being analyzed to be identified
    based on 1000 genomes population group. 
    """
    population_map = {}

    for feat_set in client.search_features(feature_set.id):

        bio_sample = client.get_biosample(feat_set.biosample_id)
        pop_group = bio_sample.info['Population'].values[0].string_value
        print ( pop_group )

    return population_map

# %%
# for random sampling genes on each chromosome 
def get_gene_regions():

    """
    randomly samples 10 genes from each chromosome and finds their start and end positions
    :return: dictionary of chromosomes with 10 genes for each chromosome and their positions
    """

    rrd = get_random_regions()

    regions = {}
    for chrom,region in rrd.iteritems():

        genes = {}
        stop = chrom_len_dict[chrom]
        for features in client.search_features(feature_set_id=feature_set.id,feature_types=['gene'],start=region, end=stop):

            if len(genes) == 3: break 

            genes[features.gene_symbol] = (int(features.start), int(features.end))

        regions[chrom] = genes

    return regions

# %%
from collections import defaultdict
# for getting allele frequencies from random sampled genes in their respective regions 
def get_af_for_genes(genes):
    """
    finds at least 10 allele frequencies for random sampled genes
    """
    pop_dict = {}
    with open('mxl.json') as data_file:
        pop_dict = json.load(data_file)

    cs_ids = pop_dict.keys()
    n = float(len(pop_dict))
    chrom_dict = {}
    for chrom,genes in genes.iteritems():
        print ("Chromosome: " + str(chrom))
        gene_dict = {} 
        for gene,positions in genes.iteritems():
            print ("Gene: " + str(gene))
            print ("Gene positions: " + str(positions[0]) + " to " + str(positions[1] ))
            i = 0
            individual_dict = {}
            allele_dict = defaultdict(list)
            alleles = []
            for v in client.search_variants(variant_set_id=release.id,call_set_ids=cs_ids,
                start= positions[0],end=positions[1], reference_name=chrom):
                if i > 50: break
                count = 0.0
                for co in v.calls:
                 
                    if len(co.genotype) > 1:
                        A1 = co.genotype[0]
                        A2 = co.genotype[1]
                    else:
                        A1 = co.genotype[0]
                        A2 = 0
                    if (((A1 + A2 ) > 0)):
                        count += 1

                af = count / n 
                if ( af > 0.0 and len(v.names) > 0 ):
                    print( "Allele frequency for variant " + str(v.names[0]) + " is " + str(af))
                    allele_dict[v.names[0]].append(af)
                i += 1
            gene_dict[gene] = allele_dict
            print()
        print()
        chrom_dict[chrom] = gene_dict

    return chrom_dict

# %%
genes = {}
genes = get_gene_regions()

chrom_dict = {}
chrom_dict = get_af_for_genes(genes)
# Out:
# Chromosome: 20
# Gene: CHCHD3P3
# Gene positions: 27527325 to 27527964
#
# Gene: SLC9A1
# Gene positions: 27425306 to 27493472
#
# Gene: RP11-40H20.5
# Gene positions: 27503242 to 27503768
#
#
# Chromosome: 21
# Gene: ZNF436
# Gene positions: 23685941 to 23695935
# Allele frequency for variant rs13046653 is 0.15625
# Allele frequency for variant rs149184458 is 0.015625
# Allele frequency for variant rs2212882 is 1.0
# Allele frequency for variant rs2226809 is 1.0
# Allele frequency for variant rs2226810 is 0.125
# Allele frequency for variant rs2827397 is 0.171875
# Allele frequency for variant rs17510988 is 0.046875
# Allele frequency for variant rs9978134 is 1.0
# Allele frequency for variant rs13051400 is 1.0
# Allele frequency for variant rs2827398 is 1.0
# Allele frequency for variant rs202191269 is 0.015625
# Allele frequency for variant rs115660071 is 0.125
# Allele frequency for variant rs12626763 is 1.0
# Allele frequency for variant rs2827399 is 1.0
# ...

# %%
def get_data_matrix(chrom_dict, chrom):

    data_matrix = []
    name_row = ['gene','variant','allele frequency']
    data_matrix.append(name_row)
    for gene, allele_dict in chrom_dict[chrom].iteritems():
        row = []
        row.append(gene)
        alleles = allele_dict.keys()
        i = 0
        for allele in alleles:
            if i >= 1:
                row.append(" ")
            row.append(allele)
            row.append( list(allele_dict[allele] )[0] )
            i += 1
            data_matrix.append(row)
            row = []

    return data_matrix

# %%
data_matrix = get_data_matrix(chrom_dict, str(1))

# %%
import plotly
import plotly.plotly as py
import plotly.figure_factory as ff

plotly.tools.set_credentials_file(username='nishill', api_key='XnMkHhoL9H5PwPKIcwr9')


data_matrix = get_data_matrix(chrom_dict, str(1))
table = ff.create_table(data_matrix, index=True)

# Make text size larger
for i in range(len(table.layout.annotations)):
    table.layout.annotations[i].font.size = 10

py.iplot(table, filename='index_table')
# Out:
# High five! You successfuly sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~nishill/0 or inside your plot.ly account where it is named 'index_table'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~nishill/0.embed" height="740px" width="100%"></iframe>

# %%
import plotly.plotly as py
import plotly.figure_factory as ff

py.tools.set_credentials_file(username='nishill', api_key='XnMkHhoL9H5PwPKIcwr9')

for chrom,gene_dict in chrom_dict.iteritems():

    data_matrix = get_data_matrix(chrom_dict, chrom)
    table = ff.create_table(data_matrix, index=True)

    # Make text size larger
    for i in range(len(table.layout.annotations)):
        table.layout.annotations[i].font.size = 20

    py.iplot(table, filename='index_table',account='nishill')
    #py.iplot(table, url='http://localhost:8888/notebooks/populations.ipynb#get-feature_set')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-f6451b413e0e> in <module>()
#       2 import plotly.figure_factory as ff
#       3
# ----> 4 py.tools.set_credentials_file(username='nishill', api_key='XnMkHhoL9H5PwPKIcwr9')
#       5
#       6 for chrom,gene_dict in chrom_dict.iteritems():
#
# AttributeError: 'module' object has no attribute 'tools'
